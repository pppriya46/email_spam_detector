# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import pickle
pd.options.mode.chained_assignment = None

# %%
from keras.models import load_model
model = load_model('model.h5')

# %%
with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 64)           1280000
#
#  dropout (Dropout)           (None, 150, 64)           0
#
#  bidirectional (Bidirectiona  (None, 150, 64)          25088
#  l)
#
#  dropout_1 (Dropout)         (None, 150, 64)           0
#
#  bidirectional_1 (Bidirectio  (None, 150, 128)         49920
#  nal)
#
#  dropout_2 (Dropout)         (None, 150, 128)          0
#
#  bidirectional_2 (Bidirectio  (None, 64)               41472
#  nal)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 1,396,545
# Trainable params: 1,396,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
benchmark = pd.read_csv('SpamAssassin.csv')
benchmark
# Out:
#                                                   email  label
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...      0
# 1     martin a posted tassos papadopoulos the greek ...      0
# 2     man threatens explosion in moscow thursday aug...      0
# 3     klez the virus that won t die already the most...      0
# 4      in adding cream to spaghetti carbonara which ...      0
# ...                                                 ...    ...
# 2995   abc s good morning america ranks it the NUMBE...      1
# 2996   hyperlink hyperlink hyperlink let mortgage le...      1
# 2997   thank you for shopping with us gifts for all ...      1
# 2998   the famous ebay marketing e course learn to s...      1
# 2999   hello this is chinese traditional 子 件 NUMBER世...      1
#
# [3000 rows x 2 columns]

# %%
benchmark.rename(columns={'email': 'Message', 'label': 'Label'}, inplace=True)
benchmark.dropna(inplace=True)
benchmark.reset_index(drop=True, inplace=True)

# %%
spam = benchmark[benchmark['Label'] == 1]
ham = benchmark[benchmark['Label'] == 0]
ham_500 = ham.iloc[0:500, :]
bench = pd.concat([spam, ham_500], axis=0)

# %%
benchmark_message = benchmark.Message.astype(str)

seq = tokenizer.texts_to_sequences(benchmark_message)
pad = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=150, padding='post', truncating='post')

prediction = model.predict(pad)

benchmark['Prediction'] = pd.DataFrame(prediction)
benchmark.loc[(benchmark['Prediction'] > 0.5), 'Classification'] = 'spam'
benchmark.fillna('not spam', inplace=True)

# %%
benchmark
# Out:
#                                                 Message  Label  Prediction  \
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...      0    0.005452
# 1     martin a posted tassos papadopoulos the greek ...      0    0.009881
# 2     man threatens explosion in moscow thursday aug...      0    0.011408
# 3     klez the virus that won t die already the most...      0    0.009555
# 4      in adding cream to spaghetti carbonara which ...      0    0.018249
# ...                                                 ...    ...         ...
# 2994   abc s good morning america ranks it the NUMBE...      1    0.995949
# 2995   hyperlink hyperlink hyperlink let mortgage le...      1    0.996177
# 2996   thank you for shopping with us gifts for all ...      1    0.996081
# 2997   the famous ebay marketing e course learn to s...      1    0.996218
# 2998   hello this is chinese traditional 子 件 NUMBER世...      1    0.996104
#
#      Classification
# 0          not spam
# 1          not spam
# 2          not spam
# 3          not spam
# 4          not spam
# ...             ...
# 2994           spam
# 2995           spam
# 2996           spam
# 2997           spam
# 2998           spam
#
# [2999 rows x 4 columns]

# %%
benchmark.to_csv('Benchmark Results_Combined.csv')

# %%
benchmark['Label'].value_counts()
# Out:
# 0    2500
# 1     499
# Name: Label, dtype: int64

# %%
benchmark['Classification'].value_counts()
# Out:
# not spam    2413
# spam         586
# Name: Classification, dtype: int64

# %%
spam_message = spam.Message.astype(str)

seq1 = tokenizer.texts_to_sequences(spam_message)
pad1 = tf.keras.preprocessing.sequence.pad_sequences(seq1, maxlen=150, padding='post', truncating='post')

prediction = model.predict(pad1)

spam['Prediction'] = pd.DataFrame(prediction)
spam.loc[(spam['Prediction'] > 0.5), 'Classification'] = 'spam'
spam.fillna('not spam', inplace=True)

# %%
spam
# Out:
#                                                 Message  Label Prediction  \
# 2500   save up to NUMBER on life insurance why spend...      1   not spam
# 2501  NUMBER fight the risk of cancer URL NUMBER sli...      1   not spam
# 2502  NUMBER fight the risk of cancer URL NUMBER sli...      1   not spam
# 2503   adult club offers free membership instant acc...      1   not spam
# 2504  i thought you might like these NUMBER slim dow...      1   not spam
# ...                                                 ...    ...        ...
# 2994   abc s good morning america ranks it the NUMBE...      1   not spam
# 2995   hyperlink hyperlink hyperlink let mortgage le...      1   not spam
# 2996   thank you for shopping with us gifts for all ...      1   not spam
# 2997   the famous ebay marketing e course learn to s...      1   not spam
# 2998   hello this is chinese traditional 子 件 NUMBER世...      1   not spam
#
#      Classification
# 2500       not spam
# 2501       not spam
# 2502       not spam
# 2503       not spam
# 2504       not spam
# ...             ...
# 2994       not spam
# 2995       not spam
# 2996       not spam
# 2997       not spam
# 2998       not spam
#
# [499 rows x 4 columns]

# %%
spam.to_csv('Benchmark Results_Spam.csv')

# %%
spam['Label'].value_counts()
# Out:
# 1    499
# Name: Label, dtype: int64

# %%
spam['Classification'].value_counts()
# Out:
# not spam    499
# Name: Classification, dtype: int64

# %%
ham_message = ham.Message.astype(str)

seq2 = tokenizer.texts_to_sequences(ham_message)
pad2 = tf.keras.preprocessing.sequence.pad_sequences(seq2, maxlen=150, padding='post', truncating='post')

prediction = model.predict(pad2)

ham['Prediction'] = pd.DataFrame(prediction)
ham.loc[(ham['Prediction'] > 0.5), 'Classification'] = 'spam'
ham.fillna('not spam', inplace=True)

# %%
ham
# Out:
#                                                 Message  Label  Prediction  \
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...      0    0.005452
# 1     martin a posted tassos papadopoulos the greek ...      0    0.009881
# 2     man threatens explosion in moscow thursday aug...      0    0.011408
# 3     klez the virus that won t die already the most...      0    0.009555
# 4      in adding cream to spaghetti carbonara which ...      0    0.018249
# ...                                                 ...    ...         ...
# 2495  man killed trying to surf on tube train ananov...      0    0.006994
# 2496  hi gianni a very good resource for this is URL...      0    0.005793
# 2497  gianni ponzi wrote i have a prob when trying t...      0    0.004669
# 2498  neale pickett neale woozle org writes skip mon...      0    0.004650
# 2499   hi i think you need to give us a little more ...      0    0.006654
#
#      Classification
# 0          not spam
# 1          not spam
# 2          not spam
# 3          not spam
# 4          not spam
# ...             ...
# 2495       not spam
# 2496       not spam
# 2497       not spam
# 2498       not spam
# 2499       not spam
#
# [2500 rows x 4 columns]

# %%
ham.to_csv('Benchmark Results_Ham.csv')

# %%
ham['Label'].value_counts()
# Out:
# 0    2500
# Name: Label, dtype: int64

# %%
ham['Classification'].value_counts()
# Out:
# not spam    2394
# spam         106
# Name: Classification, dtype: int64

# %%
bench_message = bench.Message.astype(str)

seq3 = tokenizer.texts_to_sequences(bench_message)
pad3 = tf.keras.preprocessing.sequence.pad_sequences(seq3, maxlen=150, padding='post', truncating='post')

prediction = model.predict(pad3)

bench['Prediction'] = pd.DataFrame(prediction)
bench.loc[(bench['Prediction'] > 0.5), 'Classification'] = 'spam'
bench.fillna('not spam', inplace=True)

# %%
bench
# Out:
#                                                 Message  Label Prediction  \
# 2500   save up to NUMBER on life insurance why spend...      1   not spam
# 2501  NUMBER fight the risk of cancer URL NUMBER sli...      1   not spam
# 2502  NUMBER fight the risk of cancer URL NUMBER sli...      1   not spam
# 2503   adult club offers free membership instant acc...      1   not spam
# 2504  i thought you might like these NUMBER slim dow...      1   not spam
# ...                                                 ...    ...        ...
# 495   on NUMBER NUMBER NUMBER NUMBER NUMBER am gary ...      0   0.996177
# 496   robert harley gordon mohr wrote definitional n...      0   0.996081
# 497   on sun NUMBER sep NUMBER gordon mohr wrote ok ...      0   0.996218
# 498    j james rogers jamesr best com writes j an ex...      0   0.996104
# 499   on NUMBER NUMBER NUMBER NUMBER NUMBER am gary ...      0   0.005452
#
#      Classification
# 2500       not spam
# 2501       not spam
# 2502       not spam
# 2503       not spam
# 2504       not spam
# ...             ...
# 495            spam
# 496            spam
# 497            spam
# 498            spam
# 499        not spam
#
# [999 rows x 4 columns]

# %%
bench.to_csv('Benchmark Results_Balanced.csv')

# %%
bench['Label'].value_counts()
# Out:
# 0    500
# 1    499
# Name: Label, dtype: int64

# %%
bench['Classification'].value_counts()
# Out:
# not spam    519
# spam        480
# Name: Classification, dtype: int64
